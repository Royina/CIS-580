# %% [markdown]
# # CIS580 Final Homework

# %% [markdown]
# ## 1. Two View Stereo

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import cv2

EPS = 1e-8

from utils import viz_camera_poses

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 1)) (3.7.2)
# Requirement already satisfied: numpy in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 2)) (1.21.1)
# Collecting opencv-python (from -r requirements.txt (line 3))
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 4)) (9.3.0)
# Requirement already satisfied: scipy in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 5)) (1.10.1)
# Requirement already satisfied: nose in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 6)) (1.3.7)
# Requirement already satisfied: imageio in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 7)) (2.31.1)
# Requirement already satisfied: tqdm in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 8)) (4.66.1)
# Requirement already satisfied: pyrender in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 9)) (0.1.45)
# Requirement already satisfied: trimesh in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 10)) (3.23.5)
# Requirement already satisfied: transforms3d in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 11)) (0.4.1)
# Collecting celluloid (from -r requirements.txt (line 12))
#   Using cached celluloid-0.2.0-py3-none-any.whl (5.4 kB)
# Collecting k3d (from -r requirements.txt (line 13))
#   Obtaining dependency information for k3d from https://files.pythonhosted.org/packages/71/b7/f63b644a223704a0adc3d46507b9146c9df52fb93965629b5b31eb144fdb/k3d-2.16.0-py3-none-any.whl.metadata
#   Using cached k3d-2.16.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: open3d in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 14)) (0.17.0)
# Requirement already satisfied: plotly in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from -r requirements.txt (line 15)) (5.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: colorama in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from tqdm->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: freetype-py in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from pyrender->-r requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: networkx in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from pyrender->-r requirements.txt (line 9)) (3.0)
# Requirement already satisfied: pyglet>=1.4.10 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from pyrender->-r requirements.txt (line 9)) (1.5.27)
# Requirement already satisfied: PyOpenGL>=3.1.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from pyrender->-r requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: six in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from pyrender->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=7.0.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from k3d->-r requirements.txt (line 13)) (8.1.0)
# Collecting msgpack (from k3d->-r requirements.txt (line 13))
#   Obtaining dependency information for msgpack from https://files.pythonhosted.org/packages/40/3f/d7e9327123445429a166a86b4f3b27b161b2bba1fe0710210bd8a0a46325/msgpack-1.0.7-cp39-cp39-win_amd64.whl.metadata
#   Using cached msgpack-1.0.7-cp39-cp39-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: traitlets in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from k3d->-r requirements.txt (line 13)) (5.7.1)
# Requirement already satisfied: traittypes in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from k3d->-r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: dash>=2.6.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from open3d->-r requirements.txt (line 14)) (2.13.0)
# Requirement already satisfied: werkzeug>=2.2.3 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from open3d->-r requirements.txt (line 14)) (2.2.3)
# Requirement already satisfied: nbformat==5.7.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from open3d->-r requirements.txt (line 14)) (5.7.0)
# Requirement already satisfied: configargparse in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from open3d->-r requirements.txt (line 14)) (1.7)
# Requirement already satisfied: fastjsonschema in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (5.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from plotly->-r requirements.txt (line 15)) (8.2.3)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.2.5)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (4.4.0)
# Requirement already satisfied: requests in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.28.1)
# Requirement already satisfied: retrying in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (1.5.6)
# Requirement already satisfied: setuptools in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 14)) (68.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 1)) (3.16.2)
# Collecting comm>=0.1.3 (from ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13))
#   Obtaining dependency information for comm>=0.1.3 from https://files.pythonhosted.org/packages/7b/a6/5fd0242e974914b139451eea0a61ed9fd2e47157e33a67939043c50a94dd/comm-0.2.0-py3-none-any.whl.metadata
#   Using cached comm-0.2.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (8.12.2)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (3.0.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from werkzeug>=2.2.3->open3d->-r requirements.txt (line 14)) (2.1.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (8.1.7)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (6.8.0)
# Requirement already satisfied: backcall in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from jupyter-core->nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from jupyter-core->nbformat==5.7.0->open3d->-r requirements.txt (line 14)) (305.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from requests->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from requests->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from requests->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from requests->dash>=2.6.0->open3d->-r requirements.txt (line 14)) (2022.12.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.2.5)
# Requirement already satisfied: executing in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\royin\anaconda3\envs\pytorch-tlio\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=7.0.0->k3d->-r requirements.txt (line 13)) (0.2.2)
# Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# Using cached k3d-2.16.0-py3-none-any.whl (23.1 MB)
# Using cached msgpack-1.0.7-cp39-cp39-win_amd64.whl (222 kB)
# Using cached comm-0.2.0-py3-none-any.whl (7.0 kB)
# Installing collected packages: opencv-python, msgpack, comm, celluloid, k3d
#   Attempting uninstall: comm
#     Found existing installation: comm 0.1.2
#     Uninstalling comm-0.1.2:
#       Successfully uninstalled comm-0.1.2
# Successfully installed celluloid-0.2.0 comm-0.1.4 k3d-2.16.0 msgpack-1.0.7 opencv-python-4.8.1.78

# %% [markdown]
# ### 1.0 Load Data
#
# Note: you can uncomment the `viz_camera_poses([view_i, view_j])` to interactively understand the camera configuration, you will get some coordinates colored R-X, G-Y, B-Z. Press `i` in the interactive pyrender window to show the world coordinate.
#
# You will find that in the world frame, for each camera, X+ direction is vertically upward, the Y+ direction towards the right, and the Z+ forward.
#
# You will get views that are lying horizontally. In each image, the left-up corner has integer pixel coordinate [u,v] = [0,0]. The first index/row index of the image corresponds to Y or v, and the second index/col index of the image corresponds to X or u.

# %%
# Load data
from dataloader import load_middlebury_data
DATA = load_middlebury_data("data/templeRing")
# reference: https://vision.middlebury.edu/mview/

view_i, view_j = DATA[0], DATA[3]
viz_camera_poses([view_i, view_j])

plt.subplot(1, 2, 1)
plt.title("Sample: left view (reference)")
plt.imshow(view_i["rgb"])
plt.subplot(1, 2, 2)
plt.title("Sample: right view")
plt.imshow(view_j["rgb"])
plt.show()
# Out:
# Loading data/templeRing
# 47it [00:00, 152.25it/s]

# %% [markdown]
# ### 1.1 Rectify two views
#
# <!-- Complete the function `compute_right2left_transformation` and `compute_rectification_R`; we have implemented the calibration `rectify_2view`  for you after you get the `R_irect` -->

# %%
from two_view_stereo import (
    rectify_2view,
    compute_rectification_R,
    compute_right2left_transformation,
)

i_R_w, i_T_w = view_i["R"], view_i["T"][:, None]  # p_i = i_R_w @ p_w + i_T_w
j_R_w, j_T_w = view_j["R"], view_j["T"][:, None]  # p_j = j_R_w @ p_w + j_T_w

i_R_j, i_T_j, B = compute_right2left_transformation(i_R_w, i_T_w, j_R_w, j_T_w)
assert i_T_j[1, 0] > 0, "here we assume view i should be on the left, not on the right"

rect_R_i = compute_rectification_R(i_T_j)

rgb_i_rect, rgb_j_rect, K_i_corr, K_j_corr = rectify_2view(
    view_i["rgb"],
    view_j["rgb"],
    rect_R_i,
    rect_R_i @ i_R_j,
    view_i["K"],
    view_j["K"],
    u_padding=20,
    v_padding=20,
)

# %%
plt.subplot(2, 2, 1)
plt.title("input view i")
plt.imshow(cv2.rotate(view_i["rgb"], cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 2)
plt.title("input view j")
plt.imshow(cv2.rotate(view_j["rgb"], cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 3)
plt.title("rect view i")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(2, 2, 4)
plt.title("rect view j")
plt.imshow(cv2.rotate(rgb_j_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Compute the disparity

# %%
from two_view_stereo import image2patch, ssd_kernel

assert K_i_corr[1, 1] == K_j_corr[1, 1], "This hw assumes the same focal Y length"
assert (K_i_corr[0] == K_j_corr[0]).all(), "This hw assumes the same K on X dim"
assert (
    rgb_i_rect.shape == rgb_j_rect.shape
), "This hw makes rectified two views to have the same shape"

h, w = rgb_i_rect.shape[:2]

d0 = K_j_corr[1, 2] - K_i_corr[1, 2]

patches_i = image2patch(rgb_i_rect.astype(float) / 255.0, 3)  # [h,w,k*k,3]
patches_j = image2patch(rgb_j_rect.astype(float) / 255.0, 3)  # [h,w,k*k,3]

vi_idx, vj_idx = np.arange(h), np.arange(h)
disp_candidates = vi_idx[:, None] - vj_idx[None, :] + d0
valid_disp_mask = disp_candidates > 0.0

# as an example
u = 400

buf_i, buf_j = patches_i[:, u], patches_j[:, u]
value = ssd_kernel(buf_i, buf_j)  # each row is one pix from left, col is the disparity
# Students, why we compute this `_upper` ?
_upper = value.max() + 1.0
value[~valid_disp_mask] = _upper

# %%
plt.subplot(1,2,1)
# Viz the  disparity-cost of u=500, v=200 on left view
v = 200
plt.title("Cost-Disparity of one left pixel")
plt.xlabel("Disparity")
plt.ylabel("Cost")
plt.plot(disp_candidates[v], value[v])
plt.subplot(1,2,2)
plt.title("The cost map of one left horizon col")
plt.xlabel("Disparity")
plt.ylabel("left pixel coordinates  v_L")
plt.imshow(value)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's do the Left-Right consistency: in above right figure, the vertical axis is the left pixel coordinates and the horizontal axis is the right pixel (disparity).
#
# When we find the minimal cost right view pixel for our reference pixel (e.g. find the minimum of the left figure), we only check the best matched right pixel patch, which corresponds to finding the minimum along the horizontal axis of the right cost map.
#
# However, the matching from the left to the right and from the right to the left should be consistent.
# So we should also check the minimum of the vertical axis and see whether this two minimum agree with each other, below is an example

# %%
# example for the pixel (u=500,v=300) from the left view
v = 300
best_matched_right_pixel = value[v].argmin()
best_matched_left_pixel = value[:,best_matched_right_pixel].argmin()
print(v, best_matched_left_pixel)
consistent_flag = best_matched_left_pixel == v
print(consistent_flag)

# example for the pixel (u=500,v=380) from the left view
v = 380
best_matched_right_pixel = value[v].argmin()
best_matched_left_pixel = value[:,best_matched_right_pixel].argmin()
print(v, best_matched_left_pixel)
consistent_flag = best_matched_left_pixel == v
print(consistent_flag)

# %% [markdown]
# Based on above example, iterate over all u, complete the function `compute_disparity_map`.
#
# Tips: for vectorized operation, you may use `take_along_axis` with `argmin` from numpy, please check the documentation from numpy to understand how to use the function

# %%
from two_view_stereo import compute_disparity_map

disp_map, consistency_mask = compute_disparity_map(
    rgb_i_rect, rgb_j_rect, d0=K_j_corr[1, 2] - K_i_corr[1, 2], k_size=5
)

# %%
plt.imshow(cv2.rotate(consistency_mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.title("L-R consistency check mask")
plt.show()

# %% [markdown]
# ### 1.3 Compute the depth map and point cloud reconstruction

# %%
from two_view_stereo import compute_dep_and_pcl

# * 3. compute depth map and filter them
dep_map, xyz_cam = compute_dep_and_pcl(disp_map, B, K_i_corr)

plt.subplot(1, 3, 1)
plt.title("rgb")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(1, 3, 2)
plt.title("raw disparity")
plt.imshow(cv2.rotate(disp_map, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.subplot(1, 3, 3)
plt.title("raw depth")
plt.imshow(cv2.rotate(dep_map, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4 Postprocessing and visualization

# %%
from two_view_stereo import postprocess

mask, pcl_world, pcl_cam, pcl_color = postprocess(
    dep_map,
    rgb_i_rect,
    xyz_cam,
    c_R_w=rect_R_i @ i_R_w,
    c_T_w=rect_R_i @ i_T_w,
    consistency_mask=consistency_mask,
    z_near=0.5,
    z_far=0.6,
)

mask = (mask > 0).astype(np.float)

plt.subplot(1, 3, 1)
plt.title("rgb")
plt.imshow(cv2.rotate(rgb_i_rect, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.subplot(1, 3, 2)
plt.title("postproc disparity")
plt.imshow(cv2.rotate(disp_map * mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.subplot(1, 3, 3)
plt.title("postproc depth")
plt.imshow(cv2.rotate(dep_map * mask, cv2.ROTATE_90_COUNTERCLOCKWISE))
plt.colorbar()
plt.show()

# %% [markdown]
# Visualization code below, use whichever function works to visually inspect your work:

# %%
import k3d
import numpy as np
## IMPORTANT: if running K3D on Google Colab, be sure to uncomment the following lines:
### COLAB SETUP ###
# from google.colab import output
# output.enable_custom_widget_manager()
# k3d.switch_to_text_protocol()
###################
def viz_3d_embedded(pcl, color):
    plot = k3d.plot(camera_auto_fit=True)
    color = color.astype(np.uint8)
    color32 = (color[:, 0] * 256**2 + color[:, 1] * 256**1 + color[:, 2] * 256**0).astype(
        np.uint32
    )
    plot += k3d.points(pcl.astype(float), color32, point_size=0.001, shader="flat")
    plot.display()

### IMPORTANT: uncomment the function below to replace the `viz_3d_embedded` function if the above implementation fails
# import plotly.graph_objects as go
# def viz_3d_embedded(point_cloud, colors=None):
#     fig = go.Figure()
#     x, y, z = point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2]
#     if colors is not None:
#         fig.add_trace(go.Scatter3d(x=x, y=y, z=z, mode='markers', marker=dict(size=0.75, color=colors)))
#     else:
#         fig.add_trace(go.Scatter3d(x=x, y=y, z=z, mode='markers', marker=dict(size=0.75)))

#     fig.update_layout(scene=dict(aspectmode="data"))
#     fig.show()

# %% [markdown]
# #### SSD Two view reconstruction results

# %%
viz_3d_embedded(pcl_world, pcl_color.astype(np.uint8))

# %% [markdown]
# #### SAD Two view reconstruction results
# <!-- ### 1.5 Put things together and try different Similarity -->

# %%
from two_view_stereo import two_view ,sad_kernel

pcl_sad, pcl_color_sad, disp_map_sad, dep_map_sad = two_view(DATA[0], DATA[2], 5, sad_kernel)
viz_3d_embedded(pcl_sad, pcl_color_sad.astype(np.uint8))

# %% [markdown]
# #### ZNCC Two view reconstruction results

# %%
from two_view_stereo import two_view, zncc_kernel

pcl_zncc, pcl_color_zncc, disp_map_zncc, dep_map_zncc = two_view(DATA[0], DATA[2], 5, zncc_kernel)
viz_3d_embedded(pcl_zncc, pcl_color_zncc.astype(np.uint8))

# %% [markdown]
# ### 1.5 Aggregation

# %%
from two_view_stereo import two_view, ssd_kernel, sad_kernel, zncc_kernel

pcl_list, pcl_color_list, disp_map_list, dep_map_list = [], [], [], []
pairs = [(0, 2), (2, 4), (5, 7), (8, 10), (13, 15), (16, 18), (19, 21), (22, 24), (25, 27)]
# for i in range(13, 28, 3):
for pair in pairs:
    i,j = pair
    _pcl, _pcl_color, _disp_map, _dep_map = two_view(DATA[i], DATA[j], 5, sad_kernel)
    pcl_list.append(_pcl)
    pcl_color_list.append(_pcl_color)
    disp_map_list.append(_disp_map)
    dep_map_list.append(_dep_map)

# %%
plot = k3d.plot(camera_auto_fit=True)
for pcl, color in zip(pcl_list, pcl_color_list):
    color = color.astype(np.uint8)
    color32 = (color[:, 0] * 256**2 + color[:, 1] * 256**1 + color[:, 2] * 256**0).astype(
        np.uint32
    )
    plot += k3d.points(pcl.astype(float), color32, point_size=0.001, shader="flat")
plot.display()

## NOTE: alternative with plotly function:
# point_cloud = np.concatenate(pcl_list, axis=0)
# colors = np.concatenate(pcl_color_list, axis=0)
# viz_3d_embedded(point_cloud, colors.astype(np.uint8))
